# %%
import torch
from torch import nn
import numpy as np
import torchaudio
import os
from numpy import sort
import numpy as np


# %matplotlib inline
import matplotlib.pyplot as plt

seed = 42

np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Data Cleaning/Creation
# ## Prepare data to input into our model

# %%
def load_audio_data(data_directory, new_sample_rate=8000):
    classes = sort(list(filter(lambda x: x[0] != '.', os.listdir(data_directory))))
    print(classes)
    

    data = []
    labels = []
    for i, c in enumerate(classes):
        for f in os.listdir(data_directory + c):
            try:
                waveform, sample_rate = torchaudio.load(data_directory + c + '/' + f)
                transform = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=new_sample_rate)
                
                data.append(transform(waveform))
                labels.append(i)
            except:
                continue

    return data, labels, classes

# %%
data_directory = 'Data/genres_original/'
data, labels, classes = load_audio_data(data_directory)
# Out:
# ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %%
#print waveform 
w = data[0]
plt.figure()
plt.title('Waveform 30 sec')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.plot(w.t().numpy())
plt.show()

# %% [markdown]
# ### Split data into train and test sets

# %%
# seperate data into training and testing so that there are equal labels in test set

#split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=seed, stratify=labels)
# make sure every tensor is the same size by padding
max_length = max([x.shape[1] for x in X_train])
X_train = [torch.nn.functional.pad(x, (0, max_length - x.shape[1])) for x in X_train]
X_test = [torch.nn.functional.pad(x, (0, max_length - x.shape[1])) for x in X_test]

# %% [markdown]
# ### Batch data

# %%
batch_size = 8
dropout_prob = 0.01
train_data = list(zip(X_train, y_train))
test_data = list(zip(X_test, y_test))
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Creating a Model and Training

# %%
class AudioClassificationModel(nn.Module):
    def __init__(self, n_input, n_channel, n_output):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Conv1d(n_input, n_channel, kernel_size=80, stride=16),
            nn.BatchNorm1d(n_channel),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(dropout_prob),
            
            nn.Conv1d(n_channel, n_channel, kernel_size=3, stride=1),
            nn.BatchNorm1d(n_channel),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(dropout_prob),
            
            nn.Conv1d(n_channel, 2*n_channel, kernel_size=3, stride=1),
            nn.BatchNorm1d(2*n_channel),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(dropout_prob),
            
            nn.Conv1d(2*n_channel, 2*n_channel, kernel_size=3, stride=1),
            nn.BatchNorm1d(2*n_channel),
            nn.ReLU(),
            nn.MaxPool1d(kernel_size=4, stride=4),
            nn.Dropout(dropout_prob),
            
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(2*n_channel, n_output)
        )


    def forward(self, x):
        return self.layers(x)

# %%
def train_audio_classification_model(model, train_loader, n_epochs, lr):
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    
    for epoch in range(n_epochs):
        model.train()
        losses = []
        for inputs, labels in train_loader:
            optimizer.zero_grad()
            y_pred = model(inputs)
           
            loss = criterion(y_pred, labels)
            losses.append(loss.item())
            loss.backward()
            optimizer.step()
        average_loss = np.mean(losses)
        print(f'Epoch {epoch+1}/{n_epochs}, Average Loss: {average_loss}')
        

def test_audio_classification_model(model, test_loader, classes):
    model.eval()
    correct = 0
    total = 0
    predictions = []
    actuals = []
    with torch.no_grad():
        for inputs, labels in test_loader:
            #make a list of predicted vs actual labels
            y_pred = model(inputs)
            _, predicted = torch.max(y_pred, 1)
            predictions.extend(predicted.numpy())
            actuals.extend(labels.numpy())
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print(f'Accuracy: {correct/total}')

    return correct / total, predictions, actuals

# %%
model = AudioClassificationModel(n_input=1, n_channel=96, n_output=len(classes))
print(model)
# Out:
# AudioClassificationModel(
#   (layers): Sequential(
#     (0): Conv1d(1, 96, kernel_size=(80,), stride=(16,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.01, inplace=False)
#     (5): Conv1d(96, 96, kernel_size=(3,), stride=(1,))
#     (6): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.01, inplace=False)
#     (10): Conv1d(96, 192, kernel_size=(3,), stride=(1,))
#     (11): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.01, inplace=False)
#     (15): Conv1d(192, 192, kernel_size=(3,), stride=(1,))
#     (16): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.01, inplace=False)
#     (20): AdaptiveAvgPool1d(output_size=1)
#     (21): Flatten(start_dim=1, end_dim=-1)
#     (22): Linear(in_features=192, out_features=10, bias=True)
#   )
# )

# %%
train_audio_classification_model(model, train_loader, n_epochs=100, lr=0.001)
# Out:
# Epoch 1/100, Average Loss: 1.9031187117099762
# Epoch 2/100, Average Loss: 1.5726910579204558
# Epoch 3/100, Average Loss: 1.4213458323478698
# Epoch 4/100, Average Loss: 1.3134171703457833
# Epoch 5/100, Average Loss: 1.2619523137807847
# Epoch 6/100, Average Loss: 1.2117340475320817
# Epoch 7/100, Average Loss: 1.1607561847567558
# Epoch 8/100, Average Loss: 1.0542610600590705
# Epoch 9/100, Average Loss: 1.0967099022865296
# Epoch 10/100, Average Loss: 1.0219661316275597
# Epoch 11/100, Average Loss: 0.9774576836824417
# Epoch 12/100, Average Loss: 0.9624540886282921
# Epoch 13/100, Average Loss: 0.8903142239153385
# Epoch 14/100, Average Loss: 0.9653481420874596
# Epoch 15/100, Average Loss: 0.8775097173452377
# Epoch 16/100, Average Loss: 0.8320181983709335
# Epoch 17/100, Average Loss: 0.8098703916370869
# Epoch 18/100, Average Loss: 0.8072744463384152
# Epoch 19/100, Average Loss: 0.6947586952149868
# Epoch 20/100, Average Loss: 0.7646630996465683
# Epoch 21/100, Average Loss: 0.7443911799788475
# Epoch 22/100, Average Loss: 0.6925890342891217
# Epoch 23/100, Average Loss: 0.6597510340809822
# Epoch 24/100, Average Loss: 0.6554978327453136
# Epoch 25/100, Average Loss: 0.6388529811799526
# Epoch 26/100, Average Loss: 0.6467644792795181
# Epoch 27/100, Average Loss: 0.617340558245778
# Epoch 28/100, Average Loss: 0.5844448912143707
# Epoch 29/100, Average Loss: 0.5398804416507482
# Epoch 30/100, Average Loss: 0.5730055553093553
# Epoch 31/100, Average Loss: 0.5634393722563982
# Epoch 32/100, Average Loss: 0.5407991820573806
# Epoch 33/100, Average Loss: 0.4874499596655369
# Epoch 34/100, Average Loss: 0.48572765961289405
# Epoch 35/100, Average Loss: 0.4734099548310041
# Epoch 36/100, Average Loss: 0.4452947074174881
# Epoch 37/100, Average Loss: 0.46114360213279726
# Epoch 38/100, Average Loss: 0.5202512377500534
# Epoch 39/100, Average Loss: 0.41755452398210763
# Epoch 40/100, Average Loss: 0.39369653902947904
# Epoch 41/100, Average Loss: 0.36400590505450964
# Epoch 42/100, Average Loss: 0.3589639003202319
# Epoch 43/100, Average Loss: 0.3792527025938034
# Epoch 44/100, Average Loss: 0.35381195176392793
# Epoch 45/100, Average Loss: 0.37668411085382103
# Epoch 46/100, Average Loss: 0.3296841359324753
# Epoch 47/100, Average Loss: 0.3457760730758309
# Epoch 48/100, Average Loss: 0.3131428954284638
# Epoch 49/100, Average Loss: 0.3342714756168425
# Epoch 50/100, Average Loss: 0.34880430342629554
# Epoch 51/100, Average Loss: 0.31078769541345536
# Epoch 52/100, Average Loss: 0.31050619028508664
# Epoch 53/100, Average Loss: 0.2540185037627816
# Epoch 54/100, Average Loss: 0.262657383531332
# Epoch 55/100, Average Loss: 0.21320229498669505
# Epoch 56/100, Average Loss: 0.29490974499844014
# Epoch 57/100, Average Loss: 0.267503994749859
# Epoch 58/100, Average Loss: 0.23949508993886412
# Epoch 59/100, Average Loss: 0.24967735915444791
# Epoch 60/100, Average Loss: 0.2216995143890381
# Epoch 61/100, Average Loss: 0.2735488807410002
# Epoch 62/100, Average Loss: 0.23885201213881374
# Epoch 63/100, Average Loss: 0.21117158035747707
# Epoch 64/100, Average Loss: 0.16748547815717757
# Epoch 65/100, Average Loss: 0.18486192224547268
# Epoch 66/100, Average Loss: 0.21643677947111428
# Epoch 67/100, Average Loss: 0.23667601691558957
# Epoch 68/100, Average Loss: 0.20366741687059403
# Epoch 69/100, Average Loss: 0.20993552717380226
# Epoch 70/100, Average Loss: 0.29186125366017224
# Epoch 71/100, Average Loss: 0.16482192182913422
# Epoch 72/100, Average Loss: 0.1474333101231605
# Epoch 73/100, Average Loss: 0.2555794061999768
# Epoch 74/100, Average Loss: 0.21142249086871742
# Epoch 75/100, Average Loss: 0.1655579758202657
# Epoch 76/100, Average Loss: 0.18000431953929363
# Epoch 77/100, Average Loss: 0.153230522046797
# Epoch 78/100, Average Loss: 0.13974060885608197
# Epoch 79/100, Average Loss: 0.14970174814108758
# Epoch 80/100, Average Loss: 0.18878367812838406
# Epoch 81/100, Average Loss: 0.15008195042144507
# Epoch 82/100, Average Loss: 0.21681847986765207
# Epoch 83/100, Average Loss: 0.10791097357869148
# Epoch 84/100, Average Loss: 0.17429496546275913
# Epoch 85/100, Average Loss: 0.1401185979694128
# Epoch 86/100, Average Loss: 0.12239712915034033
# Epoch 87/100, Average Loss: 0.119571225149557
# Epoch 88/100, Average Loss: 0.07432067518122494
# Epoch 89/100, Average Loss: 0.10470423711813055
# Epoch 90/100, Average Loss: 0.15549932137597353
# Epoch 91/100, Average Loss: 0.15103394870762712
# Epoch 92/100, Average Loss: 0.12637567152851262
# Epoch 93/100, Average Loss: 0.09359871522523462
# Epoch 94/100, Average Loss: 0.15326536488602868
# Epoch 95/100, Average Loss: 0.13350139676127581
# Epoch 96/100, Average Loss: 0.16039453055942432
# Epoch 97/100, Average Loss: 0.08767489223158918
# Epoch 98/100, Average Loss: 0.10784675223054364
# Epoch 99/100, Average Loss: 0.13320184711832553
# Epoch 100/100, Average Loss: 0.09451582779176533

# %%
#get current time to save model
import datetime
now = datetime.datetime.now()
name = 'Models/model' + now.strftime("%Y%m%d%H%M") + '.pt'
torch.save(model, name)

# %%
# model = torch.load('Models/model202404101934.pt')
# get the latest model
name = 'Models/' + sorted(filter(lambda x: x[0] != '.', os.listdir('Models/')))[-1]
#model = torch.load(name)

# %%
accuracy, predictions, actual = test_audio_classification_model(model, test_loader, classes)

def plot_confusion_matrix(y_true, y_pred, classes):
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    import pandas as pd
    import matplotlib.pyplot as plt

    cm = confusion_matrix(y_true, y_pred)
    cm = cm / cm.sum(axis=1)
    df_cm = pd.DataFrame(cm, index=classes, columns=classes)
    plt.figure(figsize=(10,7))
    sns.heatmap(df_cm, annot=True, cmap='Blues')
    plt.xlabel('Prediction')
    plt.ylabel('Label')
    plt.show()
plot_confusion_matrix(actual, predictions, classes)

#plot bar graph real vs predicted
def plot_prediction_distribution(y_true, y_pred, classes):
    for(i, c) in enumerate(classes):
        correct = 0
        wrong = 0
        for j in range(len(y_true)):
            if y_true[j] == i:
                if y_pred[j] == i:
                    correct += 1
                else:
                    wrong += 1
        plt.bar(c, correct, color='g')
        plt.bar(c, wrong, bottom=correct, color='r')
    plt.legend(['Correct', 'Wrong'])
    plt.xlabel('Classes')
    plt.ylabel('Number of Predictions')
    plt.xticks(rotation=45)
    plt.show()
            

plot_prediction_distribution(actual, predictions, classes)
# Out:
# Accuracy: 0.67

# %%
def split_audio_clips(data, labels, clip_durations):
    split_data = {dur: [] for dur in clip_durations}
    split_labels = {dur: [] for dur in clip_durations}

    for i, waveform in enumerate(data):
        for clip_duration in clip_durations:
            # Calculate the number of samples in each clip
            clip_samples = int(waveform.shape[1] / clip_duration)

            # Split the waveform into clips
            for start in range(0, waveform.shape[1], clip_samples):
                end = start + clip_samples
                if end <= waveform.shape[1]:
                    clip = waveform[:, start:end]
                    split_data[clip_duration].append(clip)
                    split_labels[clip_duration].append(labels[i])

    return split_data, split_labels

# %%
clip_durations = [3, 30]  # Clip durations in seconds
split_data, split_labels = split_audio_clips(data, labels, clip_durations)

# %%
for clip_duration in clip_durations:
    print(f"Training model for {clip_duration}-second clips...")
    
    # Prepare the data for the current clip duration
    X_train, X_test, y_train, y_test = train_test_split(split_data[clip_duration], split_labels[clip_duration], test_size=0.2, random_state=42)
    
    # Pad the clips to have equal length
    max_length = max(clip.shape[1] for clip in X_train + X_test)
    X_train = [torch.nn.functional.pad(clip, (0, max_length - clip.shape[1])) for clip in X_train]
    X_test = [torch.nn.functional.pad(clip, (0, max_length - clip.shape[1])) for clip in X_test]
    
    # Create data loaders
    train_data = list(zip(X_train, y_train))
    test_data = list(zip(X_test, y_test))
    train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)
    
    # Initialize the model
    model = AudioClassificationModel(n_input=1, n_channel=64, n_output=len(classes))
    
    # Train the model
    train_audio_classification_model(model, train_loader, n_epochs=50, lr=0.001)
    
    # Evaluate the model
    accuracy, _, _ = test_audio_classification_model(model, test_loader, classes)
    print(f"Accuracy for {clip_duration}-second clips: {accuracy:.4f}")
# Out:
# Training model for 3-second clips...
# Epoch 1/50, Average Loss: 1.671945718328158
# Epoch 2/50, Average Loss: 1.3682755744457245
# Epoch 3/50, Average Loss: 1.2384143689274787
# Epoch 4/50, Average Loss: 1.136519895195961
# Epoch 5/50, Average Loss: 1.0779069010416666
# Epoch 6/50, Average Loss: 1.016956399679184
# Epoch 7/50, Average Loss: 0.9806044611334801
# Epoch 8/50, Average Loss: 0.8978873931368192
# Epoch 9/50, Average Loss: 0.8674408972760042
# Epoch 10/50, Average Loss: 0.8328800708055496
# Epoch 11/50, Average Loss: 0.7926618573566278
# Epoch 12/50, Average Loss: 0.7161860228081545
# Epoch 13/50, Average Loss: 0.7085925151407718
# Epoch 14/50, Average Loss: 0.6816153715426723
# Epoch 15/50, Average Loss: 0.6290064188589652
# Epoch 16/50, Average Loss: 0.6196073246002197
# Epoch 17/50, Average Loss: 0.5923857326557239
# Epoch 18/50, Average Loss: 0.5582503082354864
# Epoch 19/50, Average Loss: 0.5598088440547386
# Epoch 20/50, Average Loss: 0.5093528201679388
# Epoch 21/50, Average Loss: 0.4760134648283323
# Epoch 22/50, Average Loss: 0.4624530248964826
# Epoch 23/50, Average Loss: 0.4531260133907199
# Epoch 24/50, Average Loss: 0.4378870114311576
# Epoch 25/50, Average Loss: 0.4127543191239238
# Epoch 26/50, Average Loss: 0.3997930736963948
# Epoch 27/50, Average Loss: 0.38869578413665296
# Epoch 28/50, Average Loss: 0.3613623894378543
# Epoch 29/50, Average Loss: 0.33526349293688934
# Epoch 30/50, Average Loss: 0.3324075539720555
# Epoch 31/50, Average Loss: 0.327070271850874
# Epoch 32/50, Average Loss: 0.2949969239424293
# Epoch 33/50, Average Loss: 0.27973967587575316
# Epoch 34/50, Average Loss: 0.26750207087025046
# Epoch 35/50, Average Loss: 0.24289211443935832
# Epoch 36/50, Average Loss: 0.28622689059625067
# Epoch 37/50, Average Loss: 0.2694492662263413
# Epoch 38/50, Average Loss: 0.2784239545278251
# Epoch 39/50, Average Loss: 0.27961294625575345
# Epoch 40/50, Average Loss: 0.2438478698550413
# Epoch 41/50, Average Loss: 0.2192259770197173
# Epoch 42/50, Average Loss: 0.19998348901358742
# Epoch 43/50, Average Loss: 0.1955915379524231
# Epoch 44/50, Average Loss: 0.22284256762359292
# Epoch 45/50, Average Loss: 0.18797732695626715
# Epoch 46/50, Average Loss: 0.17502237407801052
# Epoch 47/50, Average Loss: 0.20260780235752462
# Epoch 48/50, Average Loss: 0.184624096142749
# Epoch 49/50, Average Loss: 0.1600012210337445
# Epoch 50/50, Average Loss: 0.1995618041899676
# Accuracy: 0.82
# Accuracy for 3-second clips: 0.8200
# Training model for 30-second clips...
# Epoch 1/50, Average Loss: 1.6184138015066738
# Epoch 2/50, Average Loss: 1.357060088409676
# Epoch 3/50, Average Loss: 1.211679285243626
# Epoch 4/50, Average Loss: 1.1201330810178707
# Epoch 5/50, Average Loss: 1.0369882152742411
# Epoch 6/50, Average Loss: 0.9811838124100272
# Epoch 7/50, Average Loss: 0.9218188895407938
# Epoch 8/50, Average Loss: 0.8742462970095155
# Epoch 9/50, Average Loss: 0.8358042162802961
# Epoch 10/50, Average Loss: 0.799140742128795
# Epoch 11/50, Average Loss: 0.763660505200212
# Epoch 12/50, Average Loss: 0.7384623862264761
# Epoch 13/50, Average Loss: 0.7012919866600195
# Epoch 14/50, Average Loss: 0.6900753934404971
# Epoch 15/50, Average Loss: 0.6658972470990351
# Epoch 16/50, Average Loss: 0.6436186608189358
# Epoch 17/50, Average Loss: 0.6196677226313441
# Epoch 18/50, Average Loss: 0.6032241891328747
# Epoch 19/50, Average Loss: 0.586753464698876
# Epoch 20/50, Average Loss: 0.5704552924778209
# Epoch 21/50, Average Loss: 0.5633906766183086
# Epoch 22/50, Average Loss: 0.5514315480449009
# Epoch 23/50, Average Loss: 0.5352941293289284
# Epoch 24/50, Average Loss: 0.5269824093264274
# Epoch 25/50, Average Loss: 0.524472155276354
# Epoch 26/50, Average Loss: 0.5028558400626462
# Epoch 27/50, Average Loss: 0.48804827997741257
# Epoch 28/50, Average Loss: 0.48713234307080966
# Epoch 29/50, Average Loss: 0.4765527313168064
# Epoch 30/50, Average Loss: 0.4719568410835331
# Epoch 31/50, Average Loss: 0.4649941702552008
# Epoch 32/50, Average Loss: 0.45803308229030176
# Epoch 33/50, Average Loss: 0.4463948121788164
# Epoch 34/50, Average Loss: 0.4446258999703748
# Epoch 35/50, Average Loss: 0.43378677725009457
# Epoch 36/50, Average Loss: 0.43897986910618225
# Epoch 37/50, Average Loss: 0.4206427248292079
# Epoch 38/50, Average Loss: 0.4143436685195805
# Epoch 39/50, Average Loss: 0.41693571913806543
# Epoch 40/50, Average Loss: 0.409496930131703
# Epoch 41/50, Average Loss: 0.3939196262070471
# Epoch 42/50, Average Loss: 0.4043012949321724
# Epoch 43/50, Average Loss: 0.3910631876565332
# Epoch 44/50, Average Loss: 0.3916478543096397
# Epoch 45/50, Average Loss: 0.38784835727442235
# Epoch 46/50, Average Loss: 0.38200346850934586
# Epoch 47/50, Average Loss: 0.38195645613167006
# Epoch 48/50, Average Loss: 0.37538349910610946
# Epoch 49/50, Average Loss: 0.3782712218429661
# Epoch 50/50, Average Loss: 0.3671599516284233
# Accuracy: 0.740407073740407
# Accuracy for 30-second clips: 0.7404

# %% [markdown]
# ## Experiment 2 - New Music

# %%
data_directory = 'Data/genres_new/'
data, labels, classes = load_audio_data(data_directory)
#print waveform 
w = data[0]
plt.figure()
plt.title('Waveform 30 sec')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.plot(w.t().numpy())
plt.show()
# Out:
# ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %%
# seperate data into training and testing so that there are equal labels in test set

#split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=seed, stratify=labels)
# make sure every tensor is the same size by padding
max_length = max([x.shape[1] for x in X_train])
#X_train = [torch.nn.functional.pad(x, (0, max_length - x.shape[1])) for x in X_train]
X_test = [torch.nn.functional.pad(x, (0, max_length - x.shape[1])) for x in X_test]

# %%
batch_size = 8
dropout_prob = 0.01
# train_data = list(zip(X_train, y_train))
test_data = list(zip(X_test, y_test))
# train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=False)

# %%
# print model
print(model)
# Out:
# AudioClassificationModel(
#   (layers): Sequential(
#     (0): Conv1d(1, 96, kernel_size=(80,), stride=(16,))
#     (1): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.01, inplace=False)
#     (5): Conv1d(96, 96, kernel_size=(3,), stride=(1,))
#     (6): BatchNorm1d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (9): Dropout(p=0.01, inplace=False)
#     (10): Conv1d(96, 192, kernel_size=(3,), stride=(1,))
#     (11): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU()
#     (13): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (14): Dropout(p=0.01, inplace=False)
#     (15): Conv1d(192, 192, kernel_size=(3,), stride=(1,))
#     (16): BatchNorm1d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (17): ReLU()
#     (18): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (19): Dropout(p=0.01, inplace=False)
#     (20): AdaptiveAvgPool1d(output_size=1)
#     (21): Flatten(start_dim=1, end_dim=-1)
#     (22): Linear(in_features=192, out_features=10, bias=True)
#   )
# )

# %%
'''
#get current time to save model
import datetime
now = datetime.datetime.now()
name = 'Models/model_new_music' + now.strftime("%Y%m%d%H%M") + '.pt'
torch.save(new_music_model, name)
# model = torch.load('Models/model202404101934.pt')
# get the latest model
name = 'Models/' + sorted(filter(lambda x: x[0] != '.', os.listdir('Models/')))[-1]
model = torch.load(name)
'''

# %%
name = 'Models/' + sorted(filter(lambda x: x[0] != '.', os.listdir('Models/')))[-1]
model = torch.load(name)
accuracy, predictions, actual = test_audio_classification_model(model, test_loader, classes)
# Out:
# Accuracy: 0.35

# %%
plot_confusion_matrix(actual, predictions, classes)  
plot_prediction_distribution(actual, predictions, classes)
